# %% [markdown]
# steps for regression model (dummy regrresion)

# %%
#step1: import library
import pandas as pd

# %% [markdown]
# https://raw.githubusercontent.com/YBIFoundation/Dataset/refs/heads/main/Salary%20Data.csv

# %%
#step2: read dataset
ex=pd.read_csv('https://raw.githubusercontent.com/YBIFoundation/Dataset/refs/heads/main/Salary%20Data.csv')

# %%
#step3: EDA

# %%
ex.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
ex.tail()
# Out:
#     Experience Years  Salary
# 35               9.0  105582
# 36               9.5  116969
# 37               9.6  112635
# 38              10.3  122391
# 39              10.5  121872

# %%
ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 772.0 bytes

# %%
ex.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
ex.isna().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
ex.duplicated().sum()
# Out:
# np.int64(0)

# %%
#step4: define problem(y&x)
ex.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
y=ex['Salary']
x=ex[['Experience Years']]

# %%
y
# Out:
# 0      39343
# 1      42774
# 2      46205
# 3      37731
# 4      43525
# 5      39891
# 6      48266
# 7      56642
# 8      60150
# 9      54445
# 10     64445
# 11     60000
# 12     57189
# 13     60200
# 14     63218
# 15     55794
# 16     56957
# 17     57081
# 18     59095
# 19     61111
# 20     64500
# 21     67938
# 22     66029
# 23     83088
# 24     82200
# 25     81363
# 26     93940
# 27     91000
# 28     90000
# 29     91738
# 30     98273
# 31    101302
# 32    113812
# 33    111620
# 34    109431
# 35    105582
# 36    116969
# 37    112635
# 38    122391
# 39    121872
# Name: Salary, dtype: int64

# %%
#step5:split into train and test sample
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2529)

# %%
#step6:dummy model
from sklearn.dummy import DummyRegressor
model=DummyRegressor()

# %%
#step7:train model
model.fit(X_train,y_train)
# Out:
# DummyRegressor()

# %%
#step8:prediction
y__pred=model.predict(X_test)

# %%
#step9:model evaluation
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

# %%
mean_absolute_percentage_error(y_test,y__pred)
# Out:
# 0.34058766233572735
